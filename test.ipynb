# %%
import os
current_dir = os.getcwd()
print(f"当前目录: {current_dir}")
# Out:
# 当前目录: c:\Users\503\Desktop\exp\DQN_DARLA

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda
